# %% [markdown]
# Purpose: to QC Aquatic Invertebrate data file - FieldMeasured_DischargeDetail.csv

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("periods_events.csv")

# %%
df
# Out:
#                                 ParkName ParkCode             PeriodID  \
# 0                 Buffalo National River     BUFF  BUFFRMINVE2005NOV29
# 1                 Buffalo National River     BUFF  BUFFRMINVE2005NOV29
# 2                 Buffalo National River     BUFF  BUFFRMINVE2005NOV29
# 3                 Buffalo National River     BUFF  BUFFRMINVE2005NOV29
# 4                 Buffalo National River     BUFF  BUFFRMINVE2005NOV29
# ..                                   ...      ...                  ...
# 301  Wilson's Creek National Battlefield     WICR  WICRAquBug2019Jun03
# 302  Wilson's Creek National Battlefield     WICR  WICRAquBug2019Jun03
# 303  Wilson's Creek National Battlefield     WICR  WICRAquBug2022Jun02
# 304  Wilson's Creek National Battlefield     WICR  WICRAquBug2022Jun02
# 305  Wilson's Creek National Battlefield     WICR  WICRAquBug2022Jun02
#
#      Season    Period_StartDate      Period_EndDate              EventID  \
# ...

# %%
df.dtypes
# Out:
# ParkName            object
# ParkCode            object
# PeriodID            object
# Season               int64
# Period_StartDate    object
# Period_EndDate      object
# EventID             object
# Event_StartDate     object
# Event_EndDate       object
# dtype: object

# %%
df['ParkName'].unique()
# Out:
# array(['Buffalo National River', 'Effigy Mounds National Monument',
#        'George Washington Carver National Monument',
#        'Herbert Hoover National Historic Site',
#        'Homestead National Historic Site', 'Hot Springs National Park',
#        'Ozark National Scenic Riverways',
#        'Pea Ridge National Military Park', 'Pipestone National Monument',
#        'Tallgrass Prairie National Preserve',
#        "Wilson's Creek National Battlefield"], dtype=object)

# %%
df['ParkCode'].unique()
# Out:
# array(['BUFF', 'EFMO', 'GWCA', 'HEHO', 'HOME', 'HOSP', 'OZAR', 'OZRS',
#        'PERI', 'PIPE', 'TAPR', 'WICR'], dtype=object)

# %%
df['PeriodID'].unique()
# Out:
# array(['BUFFRMINVE2005NOV29', 'BUFFRMINVE2007JAN04',
#        'BUFFRMINVE2007Nov26', 'BUFFRMINVE2008Dec02',
#        'BUFFRMINVE2009Dec07', 'BUFFRMINVE2010Nov29',
#        'BUFFRMINVE2011Dec01', 'BUFFRMINVE2013Nov21',
#        'BUFFRMINVE2015Nov23', 'BUFFRMINVE2017Nov15',
#        'BUFFRMINVE2019Nov04', 'BUFFRMINVE2021Nov01',
#        'BUFFRMINVE2023Nov01', 'EFMOAqubug2008Jul09',
#        'EFMOAqubug2014Aug13', 'EFMOAquBug2017Jul18',
#        'EFMOAquBug2023Jul19', 'GWCAAqubug2006Jun27',
#        'GWCAAqubug2007Jun26', 'GWCAAqubug2010May05',
#        'GWCAAqubug2013May01', 'GWCAAquBug2016May02',
#        'GWCAAquBug2019May06', 'GWCAAquBug2022May02',
#        'HEHOAqubug2008Jul07', 'HEHOAqubug2011Jul11',
#        'HEHOAqubug2014Aug01', 'HEHOAquBug2017Jul17',
#        'HEHOAquBug2021Jul26', 'HEHOAquBug2022Jul05',
#        'HEHOAquBug2023Jul17', 'HOMEAqubug2006Aug10',
#        'HOMEAqubug2006Sep07', 'HOMEAqubug2007Aug10',
#        'HOMEAqubug2008Aug27', 'HOMEAqubug2009Sep13',
# ...

# %%
df['Season'].unique()
# Out:
# array([2005, 2006, 2007, 2008, 2009, 2010, 2011, 2013, 2015, 2017, 2019,
#        2021, 2023, 2014, 2016, 2022, 2012, 2020, 2018])

# %%
df['Period_StartDate'].unique()
# Out:
# array(['11/29/2005 0:00:00', '1/4/2007 0:00:00', '11/26/2007 0:00:00',
#        '12/2/2008 0:00:00', '12/7/2009 0:00:00', '11/29/2010 0:00:00',
#        '12/1/2011 0:00:00', '11/21/2013 0:00:00', '11/23/2015 0:00:00',
#        '11/15/2017 0:00:00', '11/4/2019 0:00:00', '11/1/2021 0:00:00',
#        '11/1/2023 0:00:00', '7/9/2008 0:00:00', '8/13/2014 0:00:00',
#        '7/18/2017 0:00:00', '7/19/2023 0:00:00', '6/27/2006 0:00:00',
#        '6/26/2007 0:00:00', '5/5/2010 0:00:00', '5/1/2013 0:00:00',
#        '5/2/2016 0:00:00', '5/6/2019 0:00:00', '5/2/2022 0:00:00',
#        '7/7/2008 0:00:00', '7/11/2011 0:00:00', '8/1/2014 0:00:00',
#        '7/17/2017 0:00:00', '7/26/2021 0:00:00', '7/5/2022 0:00:00',
#        '7/17/2023 0:00:00', '8/10/2006 0:00:00', '9/7/2006 0:00:00',
#        '8/10/2007 0:00:00', '8/27/2008 0:00:00', '9/13/2009 0:00:00',
#        '8/5/2010 0:00:00', '9/10/2010 0:00:00', '8/30/2011 0:00:00',
# ...

# %%
df['Period_EndDate'].unique()
# Out:
# array(['12/14/2005 0:00:00', '2/22/2007 0:00:00', '1/23/2008 0:00:00',
#        '2/18/2009 0:00:00', '1/21/2010 0:00:00', '12/1/2010 0:00:00',
#        '1/18/2012 0:00:00', '2/19/2014 0:00:00', '12/18/2015 0:00:00',
#        '12/8/2017 0:00:00', '11/21/2019 0:00:00', '11/10/2021 0:00:00',
#        '11/14/2023 0:00:00', '7/9/2008 0:00:00', '8/13/2014 0:00:00',
#        '7/18/2017 0:00:00', '7/19/2023 0:00:00', '6/27/2006 0:00:00',
#        '6/26/2007 0:00:00', '5/5/2010 0:00:00', '5/1/2013 0:00:00',
#        '5/2/2016 0:00:00', '5/6/2019 0:00:00', '5/2/2022 0:00:00',
#        '7/7/2008 0:00:00', '7/11/2011 0:00:00', '8/1/2014 0:00:00',
#        '7/17/2017 0:00:00', '7/28/2021 0:00:00', '7/5/2023 0:00:00',
#        '7/17/2023 0:00:00', '8/10/2006 0:00:00', '9/7/2006 0:00:00',
#        '8/10/2007 0:00:00', '8/27/2008 0:00:00', '9/15/2009 0:00:00',
#        '8/5/2010 0:00:00', '9/10/2010 0:00:00', '8/30/2011 0:00:00',
#        '8/30/2012 0:00:00', '9/6/2013 0:00:00', '9/9/2014 0:00:00',
# ...

# %%
df['EventID'].unique()
# Out:
# array(['BUFFRMINVE2005DEC14', 'BUFFRMINVE2005DEC20',
#        'BUFFRMINVE2005NOV29', 'BUFFRMINVE2005NOV30',
#        'BUFFRMINVE2005DEC01', 'BUFFRMINVE2007JAN05',
#        'BUFFRMINVE2007JAN20', 'BUFFRMINVE2007JAN08',
#        'BUFFRMINVE2007JAN04', 'BUFFRMINVE2007FEB22',
#        'BUFFRMINVE2007FEB20', 'BUFFRMINVE2007FEB09',
#        'BUFFRMINVE2007FEB21', 'BUFFRMINVE2007JAN09',
#        'BUFFRMINVE2007Nov27', 'BUFFRMINVE2008Jan22',
#        'BUFFRMINVE2008Jan23', 'BUFFRMINVE2007Dec03',
#        'BUFFRMINVE2007Nov30', 'BUFFRMINVE2007Nov28',
#        'BUFFRMINVE2007Nov26', 'BUFFRMINVE2007Dec04',
#        'BUFFRMINVE2007Nov29', 'BUFFRMINVE2009Jan08',
#        'BUFFRMINVE2008Dec11', 'BUFFRMINVE2009Feb18',
#        'BUFFRMINVE2008Dec05', 'BUFFRMINVE2008Dec04',
#        'BUFFRMINVE2008Dec10', 'BUFFRMINVE2008Dec02',
#        'BUFFRMINVE2008Dec03', 'BUFFRMINVE2010Jan11',
#        'BUFFRMINVE2010Jan21', 'BUFFRMINVE2010Jan15',
#        'BUFFRMINVE2010Jan14', 'BUFFRMINVE2010Jan12',
# ...

# %%
df['Event_StartDate'].unique()
# Out:
# array(['12/14/2005 0:00:00', '12/20/2005 0:00:00', '11/29/2005 0:00:00',
#        '11/30/2005 0:00:00', '12/1/2005 0:00:00', '1/5/2007 0:00:00',
#        '1/20/2007 0:00:00', '1/8/2007 0:00:00', '1/4/2007 0:00:00',
#        '2/22/2007 0:00:00', '2/20/2007 0:00:00', '2/9/2007 0:00:00',
#        '2/21/2007 0:00:00', '1/9/2007 0:00:00', '11/27/2007 0:00:00',
#        '1/22/2008 0:00:00', '1/23/2008 0:00:00', '12/3/2007 0:00:00',
#        '11/30/2007 0:00:00', '11/28/2007 0:00:00', '11/26/2007 0:00:00',
#        '12/4/2007 0:00:00', '11/29/2007 0:00:00', '1/8/2009 0:00:00',
#        '12/11/2008 0:00:00', '2/18/2009 0:00:00', '12/5/2008 0:00:00',
#        '12/4/2008 0:00:00', '12/10/2008 0:00:00', '12/2/2008 0:00:00',
#        '12/3/2008 0:00:00', '1/11/2010 0:00:00', '1/21/2010 0:00:00',
#        '1/15/2010 0:00:00', '1/14/2010 0:00:00', '1/12/2010 0:00:00',
#        '12/16/2009 0:00:00', '12/15/2009 0:00:00', '12/14/2009 0:00:00',
# ...

# %%
df['Event_EndDate'].unique()
# Out:
# array(['12/14/2005 0:00:00', '12/20/2005 0:00:00', '11/29/2005 0:00:00',
#        '11/30/2005 0:00:00', '12/1/2005 0:00:00', '1/5/2007 0:00:00',
#        '1/20/2007 0:00:00', '1/8/2007 0:00:00', '1/4/2007 0:00:00',
#        '2/22/2007 0:00:00', '2/20/2007 0:00:00', '2/9/2007 0:00:00',
#        '2/21/2007 0:00:00', '1/9/2007 0:00:00', '11/27/2007 0:00:00',
#        '1/22/2008 0:00:00', '1/23/2008 0:00:00', '12/3/2007 0:00:00',
#        '11/30/2007 0:00:00', '11/28/2007 0:00:00', '11/26/2007 0:00:00',
#        '12/4/2007 0:00:00', '11/29/2007 0:00:00', '1/8/2009 0:00:00',
#        '12/11/2008 0:00:00', '2/18/2009 0:00:00', '12/5/2008 0:00:00',
#        '12/4/2008 0:00:00', '12/10/2008 0:00:00', '12/2/2008 0:00:00',
#        '12/3/2008 0:00:00', '1/11/2010 0:00:00', '1/21/2010 0:00:00',
#        '1/15/2010 0:00:00', '1/14/2010 0:00:00', '1/12/2010 0:00:00',
#        '12/16/2009 0:00:00', '12/15/2009 0:00:00', '12/14/2009 0:00:00',
# ...
