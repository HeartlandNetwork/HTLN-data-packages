# %% [markdown]
# Purpose: to QC Aquatic Invertebrate data file - FieldMeasured_DischargeDetail.csv

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("measured_discharge.csv")

# %%
df
# Out:
#                     ParkName ParkCode LocationType  \
# 0     Buffalo National River     BUFF     Mainstem
# 1     Buffalo National River     BUFF     Mainstem
# 2     Buffalo National River     BUFF     Mainstem
# 3     Buffalo National River     BUFF     Mainstem
# 4     Buffalo National River     BUFF     Mainstem
# ...                      ...      ...          ...
# 3518       Wilson's Creek NB     WICR    Tributary
# 3519       Wilson's Creek NB     WICR    Tributary
# 3520       Wilson's Creek NB     WICR    Tributary
# 3521       Wilson's Creek NB     WICR    Tributary
# 3522       Wilson's Creek NB     WICR    Tributary
#
#                              LocationDescription          StreamName  \
# 0                                            NaN       Buffalo River
# 1                                            NaN       Buffalo River
# 2                                            NaN       Buffalo River
# 3                                            NaN       Buffalo River
# 4                                            NaN       Buffalo River
# ...                                          ...                 ...
# 3518  Site 1 2010; Lower Wilson's Creek (WICR 3)  Lower Wilson Creek
# 3519  Site 1 2010; Lower Wilson's Creek (WICR 3)  Lower Wilson Creek
# 3520  Site 1 2010; Lower Wilson's Creek (WICR 3)  Lower Wilson Creek
# 3521  Site 1 2010; Lower Wilson's Creek (WICR 3)  Lower Wilson Creek
# 3522  Site 1 2010; Lower Wilson's Creek (WICR 3)  Lower Wilson Creek
#
#      TributaryName  County  StretchNumber    ReachID  ReachLength_m  ...  \
# 0              NaN  Searcy           69.0    BUFFM04            NaN  ...
# 1              NaN  Searcy           69.0    BUFFM04            NaN  ...
# 2              NaN  Searcy           69.0    BUFFM04            NaN  ...
# 3              NaN  Searcy           69.0    BUFFM04            NaN  ...
# 4              NaN  Searcy           69.0    BUFFM04            NaN  ...
# ...            ...     ...            ...        ...            ...  ...
# 3518           NaN  Greene            NaN  WICRLOW02            NaN  ...
# 3519           NaN  Greene            NaN  WICRLOW02            NaN  ...
# 3520           NaN  Greene            NaN  WICRLOW02            NaN  ...
# 3521           NaN  Greene            NaN  WICRLOW02            NaN  ...
# 3522           NaN  Greene            NaN  WICRLOW02            NaN  ...
#
#       Season           StartDate             EndDate              EventID  \
# 0       2005  11/29/2005 0:00:00  12/14/2005 0:00:00  BUFFRMINVE2005DEC01
# 1       2005  11/29/2005 0:00:00  12/14/2005 0:00:00  BUFFRMINVE2005DEC01
# 2       2005  11/29/2005 0:00:00  12/14/2005 0:00:00  BUFFRMINVE2005DEC01
# 3       2005  11/29/2005 0:00:00  12/14/2005 0:00:00  BUFFRMINVE2005DEC01
# 4       2005  11/29/2005 0:00:00  12/14/2005 0:00:00  BUFFRMINVE2005DEC01
# ...      ...                 ...                 ...                  ...
# 3518    2022    6/2/2022 0:00:00   6/14/2022 0:00:00  WICRAquBug2022Jun14
# 3519    2022    6/2/2022 0:00:00   6/14/2022 0:00:00  WICRAquBug2022Jun14
# 3520    2022    6/2/2022 0:00:00   6/14/2022 0:00:00  WICRAquBug2022Jun14
# 3521    2022    6/2/2022 0:00:00   6/14/2022 0:00:00  WICRAquBug2022Jun14
# 3522    2022    6/2/2022 0:00:00   6/14/2022 0:00:00  WICRAquBug2022Jun14
#
#        Units DischargeNo DistanceFromBank_m  Depth_cm  Velocity_ms  Comments
# 0     meters           1                0.0       8.0         0.00       NaN
# 1     meters           2                2.0      20.0         0.19       NaN
# 2     meters           3                4.0      17.0         0.26       NaN
# 3     meters           4                6.0      16.0         0.22       NaN
# 4     meters           5                8.0      16.0         0.21       NaN
# ...      ...         ...                ...       ...          ...       ...
# 3518  meters          11               10.0      21.0         0.12       NaN
# 3519  meters          12               11.0      19.0         0.05       NaN
# 3520  meters          13               12.0      14.0         0.01       NaN
# 3521  meters          14               13.0      12.0         0.00       NaN
# 3522  meters          15               14.0       0.0         0.00       NaN
#
# [3523 rows x 22 columns]

# %%
df['ParkName'].unique() # Left off fixing park names in the Access database
# Out:
# array(['Buffalo National River', 'Effigy Mounds NM',
#        'George Washington Carver NM', 'Herbert Hoover NHS',
#        'Hot Springs NP', 'Ozark National Scenic Riverways - RIVERS',
#        'Pea Ridge NMP', 'Pipestone NM', 'Tallgrass Prairie NPres',
#        "Wilson's Creek NB"], dtype=object)
